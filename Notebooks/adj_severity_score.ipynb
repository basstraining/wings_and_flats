# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/final_df.csv')

# %%
df['Make:Model'].value_counts()
# Out:
# Make:Model
# Boeing737                 236
# Boeing777                  56
# Boeing767                  54
# Boeing757                  47
# Airbus320                  45
# McdonnellDouglas:MD-80     38
# Bombardier-CL600           37
# Embraer-EMB145             30
# Airbus319                  27
# Boeing747                  25
# Airbus330                  23
# Airbus321                  16
# Embraer-ERJ170             16
# McdonnellDouglas:DC-9      15
# McdonnellDouglas:DC-10     13
# Boeing727                  12
# Boeing787                   9
# Embraer-ERJ190              9
# Lockheed-L-1011             8
# Bombardier-DHC8-402         6
# Boeing717                   5
# Embraer-EMB135KL            4
# McdonnellDouglas:MD-11      4
# McdonnellDouglas:MD-90      4
# Airbus220                   3
# Airbus310                   3
# Embraer-EMB170              3
# Atr: ATR72                  3
# Dehavilland-DHC8            2
# Airbus380                   2
# Fokker-F-100                2
# Short Brothers: SD3-60      2
# Boeing82                    2
# McdonnellDouglas:DC-8       2
# Boeing707                   2
# Fokker-F28-4000             2
# Boeing10                    1
# Airbus340                   1
# Embraer-ERJ175              1
# Bombardier-DHC8-311         1
# Embraer-E175                1
# Boeing88                    1
# Airbus300                   1
# Bombardier-DHC8-202         1
# Boeing9                     1
# Boeing90                    1
# Boeing744                   1
# Saab: 2000                  1
# Name: count, dtype: int64

# %%
total_deliveries = {
    'Boeing737': 11550,
    'Boeing777': 1718,
    'Boeing767': 1288,
    'Boeing757': 1049,
    'Airbus320': 11134,
    'McdonnellDouglas:MD-80': 1191,
    'Bombardier-CL600': 1157,
    'Embraer-EMB145': 1231,
    'Airbus319': 1500,
    'Boeing747': 1574,
    'Airbus330': 1579,
    'Airbus321': 2965,
    'Embraer-ERJ170': 191,
    'McdonnellDouglas:DC-9': 2441,
    'McdonnellDouglas:DC-10': 386,
    'Boeing727': 1831,
    'Boeing787': 1040,
    'Embraer-ERJ190': 463,
    'Lockheed-L-1011': 250,
    'Bombardier-DHC8-402':1249,
    'Boeing717': 156,
    'Embraer-EMB135KL': 892,
    'McdonnellDouglas:MD-11': 200,
    'McdonnellDouglas:MD-90': 116,
    'Airbus220': 296,
    'Airbus310': 255,
    'Embraer-EMB170': 160,
    'Atr: ATR72': 1800,
    'Dehavilland-DHC8': 1232,
    'Airbus380': 251,
    'Fokker-F-100': 278,
    'Short Brothers: SD3-60': 165,
    'Boeing82': 1190,
    'McdonnellDouglas:DC-8': 556,
    'Boeing707': 1011,
    'Fokker-F28-4000': 241,
    'Boeing10': 400,
    'Airbus340': 377,
    'Embraer-ERJ175': 600,
    'Boeing88': 400,
    'Airbus300': 816,
    'Bombardier-DHC8-202': 500,
    'Boeing9': 500,
    'Boeing90': 450,
    'Boeing744': 1574,
    'Saab: 2000': 63,
}
   
df['Total Deliveries'] = df['Make:Model'].map(total_deliveries)

# %%
df.head()
# Out:
#          Event.Id Accident.Number Event.Date  Number.of.Engines Engine.Type  \
# 0  20170710X52551      NYC79AA106    9/17/79                2.0   Turbo Fan
# 1  20020917X01897      CHI82IA026    1/12/82                3.0   Turbo Fan
# 2  20020917X01909      DCA82AA013    1/23/82                3.0   Turbo Fan
# 3  20020917X01910      DCA82AA014     2/3/82                3.0   Turbo Fan
# 4  20020917X02336      LAX82IA075    2/15/82                2.0   Turbo Jet
#
#    Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                     0                       0                     1
# 1                     0                       0                     0
# 2                     2                       4                    24
# 3                     0                       1                     0
# 4                     0                       0                     0
#
#    Total.Uninjured  People.Count          City         Region  Latitude  \
# 0               44            45        Boston  Massachusetts   42.3188
# 1              149           149       Chicago       Illinois   41.8375
# 2              182           212        Boston  Massachusetts   42.3188
# 3              154           155  Philadelphia   Pennsylvania   40.0077
# 4              119           119       Ontario     California   34.0393
#
#    Longitude              Make:Model  Severity_Score   Fatality  \
# 0   -71.0852   McdonnellDouglas:DC-9      104.444444  Non-Fatal
# 1   -87.6866         Lockheed-L-1011      100.000000  Non-Fatal
# 2   -71.0852  McdonnellDouglas:DC-10      166.037736    Fatal-2
# 3   -75.1339  McdonnellDouglas:DC-10      107.096774  Non-Fatal
# 4  -117.6064               Boeing737      100.000000  Non-Fatal
#
#    Total Deliveries
# 0            2441.0
# 1             250.0
# 2             386.0
# 3             386.0
# 4           11550.0

# %%
df['Adjusted Severity_Score'] = (df['Severity_Score'] / df['Total Deliveries']) * 250
df.head()
# Out:
#          Event.Id Accident.Number Event.Date  Number.of.Engines Engine.Type  \
# 0  20170710X52551      NYC79AA106    9/17/79                2.0   Turbo Fan
# 1  20020917X01897      CHI82IA026    1/12/82                3.0   Turbo Fan
# 2  20020917X01909      DCA82AA013    1/23/82                3.0   Turbo Fan
# 3  20020917X01910      DCA82AA014     2/3/82                3.0   Turbo Fan
# 4  20020917X02336      LAX82IA075    2/15/82                2.0   Turbo Jet
#
#    Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                     0                       0                     1
# 1                     0                       0                     0
# 2                     2                       4                    24
# 3                     0                       1                     0
# 4                     0                       0                     0
#
#    Total.Uninjured  People.Count          City         Region  Latitude  \
# 0               44            45        Boston  Massachusetts   42.3188
# 1              149           149       Chicago       Illinois   41.8375
# 2              182           212        Boston  Massachusetts   42.3188
# 3              154           155  Philadelphia   Pennsylvania   40.0077
# 4              119           119       Ontario     California   34.0393
#
#    Longitude              Make:Model  Severity_Score   Fatality  \
# 0   -71.0852   McdonnellDouglas:DC-9      104.444444  Non-Fatal
# 1   -87.6866         Lockheed-L-1011      100.000000  Non-Fatal
# 2   -71.0852  McdonnellDouglas:DC-10      166.037736    Fatal-2
# 3   -75.1339  McdonnellDouglas:DC-10      107.096774  Non-Fatal
# 4  -117.6064               Boeing737      100.000000  Non-Fatal
#
#    Total Deliveries  Adjusted Severity_Score
# 0            2441.0                10.696891
# 1             250.0               100.000000
# 2             386.0               107.537394
# 3             386.0                69.363196
# 4           11550.0                 2.164502

# %%
grouped_df = df.groupby('Make:Model').agg({
    'Adjusted Severity_Score': 'mean',
    'Total Deliveries': 'mean',
    'Total.Fatal.Injuries': 'sum',
    'Total.Serious.Injuries': 'sum',
    'Total.Minor.Injuries': 'sum',
    'Total.Uninjured': 'sum',
    'Make:Model': 'size'
})

# %%
Sorted_df = grouped_df.sort_values('Adjusted Severity_Score', ascending=True)
Sorted_df
# Out:
#                         Adjusted Severity_Score  Total Deliveries  \
# Make:Model
# Airbus320                              3.670950           11134.0
# Boeing737                              4.907782           11550.0
# McdonnellDouglas:DC-9                 11.843467            2441.0
# Atr: ATR72                            13.888889            1800.0
# Boeing744                             15.883100            1574.0
# Dehavilland-DHC8                      20.292208            1232.0
# Embraer-EMB145                        21.029687            1231.0
# Airbus319                             21.131053            1500.0
# Airbus321                             21.167247            2965.0
# McdonnellDouglas:MD-80                21.838936            1191.0
# Bombardier-CL600                      24.947122            1157.0
# Boeing787                             25.238246            1040.0
# Boeing707                             27.475547            1011.0
# Embraer-EMB135KL                      28.026906             892.0
# Boeing777                             29.303269            1718.0
# Boeing727                             32.541416            1831.0
# Airbus300                             33.201607             816.0
# Boeing747                             33.487546            1574.0
# Boeing757                             36.616970            1049.0
# Boeing767                             38.829346            1288.0
# Embraer-ERJ175                        42.808219             600.0
# Airbus330                             49.438090            1579.0
# Boeing9                               50.000000             500.0
# Bombardier-DHC8-202                   50.000000             500.0
# McdonnellDouglas:DC-8                 52.832595             556.0
# Boeing90                              55.555556             450.0
# Boeing88                              62.500000             400.0
# Airbus340                             66.312997             377.0
# Airbus220                             84.459459             296.0
# McdonnellDouglas:DC-10                85.895230             386.0
# Airbus380                             99.601594             251.0
# Lockheed-L-1011                      101.241438             250.0
# Bombardier-DHC8-402                  101.392589            1249.0
# Boeing10                             105.208333             400.0
# Embraer-ERJ170                       148.177507             191.0
# Short Brothers: SD3-60               151.515152             165.0
# Embraer-EMB170                       164.032567             160.0
# McdonnellDouglas:MD-11               164.432177             200.0
# Boeing717                            164.999840             156.0
# Embraer-ERJ190                       171.025539             463.0
# McdonnellDouglas:MD-90               216.270798             116.0
# Boeing82                             248.925151            1190.0
# Saab: 2000                           954.270597              63.0
# Fokker-F-100                        1127.156527             278.0
# Fokker-F28-4000                     1437.165775             241.0
# Airbus310                           1731.753100             255.0
# Bombardier-DHC8-311                         NaN               NaN
# Embraer-E175                                NaN               NaN
#
#                         Total.Fatal.Injuries  Total.Serious.Injuries  \
# Make:Model
# Airbus320                                100                      53
# Boeing737                               1314                     683
# McdonnellDouglas:DC-9                      3                       4
# Atr: ATR72                                 0                       0
# Boeing744                                  0                       0
# Dehavilland-DHC8                           0                       0
# Embraer-EMB145                             0                       3
# Airbus319                                  0                      68
# Airbus321                                157                       1
# McdonnellDouglas:MD-80                     2                      13
# Bombardier-CL600                           0                      37
# Boeing787                                  0                       6
# Boeing707                                  1                       0
# Embraer-EMB135KL                           0                       0
# Boeing777                                537                     193
# Boeing727                                 77                       1
# Airbus300                                  0                       1
# Boeing747                                228                     103
# Boeing757                                161                      22
# Boeing767                                190                     172
# Embraer-ERJ175                             0                       0
# Airbus330                                331                      13
# Boeing9                                    0                       0
# Bombardier-DHC8-202                        0                       0
# McdonnellDouglas:DC-8                      0                       1
# Boeing90                                   0                       0
# Boeing88                                   0                       0
# Airbus340                                  0                       0
# Airbus220                                  0                       0
# McdonnellDouglas:DC-10                    20                      28
# Airbus380                                  0                       0
# Lockheed-L-1011                            0                       1
# Bombardier-DHC8-402                       49                       2
# Boeing10                                   0                      11
# Embraer-ERJ170                             0                       9
# Short Brothers: SD3-60                     0                       0
# Embraer-EMB170                             0                       1
# McdonnellDouglas:MD-11                     0                       0
# Boeing717                                  0                       1
# Embraer-ERJ190                            42                      74
# McdonnellDouglas:MD-90                     0                       0
# Boeing82                                 154                       0
# Saab: 2000                                 1                       3
# Fokker-F-100                              97                       4
# Fokker-F28-4000                           27                      72
# Airbus310                                351                       0
# Bombardier-DHC8-311                        0                       0
# Embraer-E175                               0                       0
#
#                         Total.Minor.Injuries  Total.Uninjured  Make:Model
# Make:Model
# Airbus320                                 21             7112          45
# Boeing737                                189            30499         236
# McdonnellDouglas:DC-9                     55             1277          15
# Atr: ATR72                                 0              142           3
# Boeing744                                  0              159           1
# Dehavilland-DHC8                           0              104           2
# Embraer-EMB145                             8             2119          30
# Airbus319                                 27             3359          27
# Airbus321                                  4             2575          16
# McdonnellDouglas:MD-80                    10             5748          38
# Bombardier-CL600                           7             2796          37
# Boeing787                                  5             2015           9
# Boeing707                                  3              247           2
# Embraer-EMB135KL                           0              223           4
# Boeing777                                 93            14746          56
# Boeing727                                  1             1179          12
# Airbus300                                  4              222           1
# Boeing747                                391             7962          25
# Boeing757                                 13             7979          47
# Boeing767                                 29             9248          54
# Embraer-ERJ175                             1               72           1
# Airbus330                                 30             5298          23
# Boeing9                                    0              130           1
# Bombardier-DHC8-202                        0               66           1
# McdonnellDouglas:DC-8                     18              238           2
# Boeing90                                   0              101           1
# Boeing88                                   0              147           1
# Airbus340                                  0              397           1
# Airbus220                                  0              352           3
# McdonnellDouglas:DC-10                   135             2786          13
# Airbus380                                  0             1097           2
# Lockheed-L-1011                            9             2594           8
# Bombardier-DHC8-402                        1              272           6
# Boeing10                                   1              168           1
# Embraer-ERJ170                            11             1287          16
# Short Brothers: SD3-60                     0              678           2
# Embraer-EMB170                             1              443           3
# McdonnellDouglas:MD-11                   200              843           4
# Boeing717                                  3              502           5
# Embraer-ERJ190                            30              619           9
# McdonnellDouglas:MD-90                     1              540           4
# Boeing82                                  18              137           2
# Saab: 2000                                 1               37           1
# Fokker-F-100                               2               51           2
# Fokker-F28-4000                           15                3           2
# Airbus310                                 11              184           3
# Bombardier-DHC8-311                        1               52           1
# Embraer-E175                               1               65           1

# %%
filepath = '../Data/plane_adj_severity.csv'

Sorted_df.to_csv(filepath, index=False)
