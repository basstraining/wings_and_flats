# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plane_data_75 = pd.read_csv('Plane_Data/removed_25th_per.csv')
plane_data_75
# Out:
#             Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0     20170710X52551           Accident      NYC79AA106  1979-09-17
# 1     20020917X01897           Incident      CHI82IA026  1982-01-12
# 2     20020917X01909           Accident      DCA82AA013  1982-01-23
# 3     20020917X01910           Accident      DCA82AA014  1982-02-03
# 4     20020917X02336           Incident      LAX82IA075  1982-02-15
# ...              ...                ...             ...         ...
# 2282  20221115106296           Accident      CEN23LA037  2022-11-15
# 2283  20221121106337           Accident      ANC23LA006  2022-11-20
# 2284  20221122106339           Accident      GAA23WA029  2022-11-21
# 2285  20221213106455           Accident      WPR23LA065  2022-12-13
# 2286  20221219106475           Accident      WPR23LA069  2022-12-15
#
#               Location Injury.Severity Aircraft.damage Aircraft.Category  \
# 0           BOSTON, MA       Non-Fatal     Substantial          Airplane
# ...

# %%
new_pd_75 = plane_data_75['Make:Model'] = plane_data_75['Make']+': '+ plane_data_75['Model']

# %%
new_pd_75.value_counts()
# Out:
# Boeing: 737                      336
# Boeing: 777                       66
# Airbus: A320                      62
# Boeing: 747                       58
# Boeing: 767                       50
#                                 ...
# Boeing: 737-3A4                    1
# Mcdonnell Douglas: DC3C S1C3G      1
# Airbus: A 310                      1
# Swearingen: SA-226TC               1
# Mcdonnell Douglas: DC-10-30F       1
# Length: 695, dtype: int64
