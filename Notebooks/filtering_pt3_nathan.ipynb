# %%
import pandas as pd

# %%
df = pd.read_csv("Plane_Data/new_plane_df.csv")

# %%
df["Make:Model"].value_counts()
# Out:
# Boeing: 737                336
# Boeing: 777                 66
# Airbus: A320                62
# Boeing: 747                 58
# Boeing: 767                 50
#                           ...
# British Aerospace: 800A      1
# Boeing: 737-2A5              1
# Boeing: 777-300              1
# Boeing: B-747-121            1
# Boeing: 727-233              1
# Name: Make:Model, Length: 745, dtype: int64

# %%
df.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Event.Date', 'Location',
#        'Injury.Severity', 'Registration.Number', 'Number.of.Engines',
#        'Engine.Type', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Make:Model'],
#       dtype='object')

# %%
df.shape
# Out:
# (2350, 14)

# %%
df['People.Count'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries'] + df['Total.Minor.Injuries'] + df['Total.Uninjured']

# %%
df.head(15)
# Out:
#           Event.Id Accident.Number  Event.Date          Location  \
# 0   20170710X52551      NYC79AA106  1979-09-17        BOSTON, MA
# 1   20020917X01897      CHI82IA026  1982-01-12       CHICAGO, IL
# 2   20020917X02397      MIA82FA034  1982-01-19         MIAMI, FL
# 3   20020917X01909      DCA82AA013  1982-01-23        BOSTON, MA
# 4   20020917X01910      DCA82AA014  1982-02-03  PHILADELPHIA, PA
# 5   20020917X02336      LAX82IA075  1982-02-15       ONTARIO, CA
# 6   20020917X02151      FTW82IA062  1982-02-19     HARLINGEN, TX
# 7   20020917X02477      MKC82IA042  1982-03-08     LAS VEGAS, NV
# 8   20020917X02338      LAX82IA103  1982-03-10    LONG BEACH, CA
# 9   20020917X01989      DEN82IA049  1982-03-25        DENVER, CO
# 10  20020917X01904      CHI82IA117  1982-04-09    YOUNGSTOWN, OH
# 11  20020917X02079      FTW82DA139  1982-04-18        AUSTIN, TX
# 12  20020917X02421      MIA82IA102  1982-04-20         MIAMI, FL
# ...

# %%
df['Number.of.Engines'].value_counts()
# Out:
# 2.0    1084
# 1.0     320
# 4.0      73
# 3.0      48
# 0.0       3
# Name: Number.of.Engines, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# Creating the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x=df.index, y=df['People.Count'])

# Adding labels and title
plt.xlabel('Row Index')
plt.ylabel('Total People')
plt.title('Scatter Plot of Total People Values')

# Displaying the plot
plt.show()

# %%
df['People.Count'].describe()
# Out:
# count    2350.000000
# mean       57.557447
# std        89.116227
# min         0.000000
# 25%         1.000000
# 50%         5.000000
# 75%       106.750000
# max       588.000000
# Name: People.Count, dtype: float64

# %%
clean_df = df[df['People.Count'] >= 20]
clean_df['People.Count'].describe()
# Out:
# count    904.000000
# mean     145.330752
# std       90.031901
# min       20.000000
# 25%       79.000000
# 50%      137.000000
# 75%      184.250000
# max      588.000000
# Name: People.Count, dtype: float64

# %%
clean_df1 = df[df['People.Count'] >= 40]
clean_df1['People.Count'].describe()
# Out:
# count    828.000000
# mean     155.892512
# std       86.710441
# min       40.000000
# 25%       99.000000
# 50%      143.000000
# 75%      189.000000
# max      588.000000
# Name: People.Count, dtype: float64

# %%
clean_df2 = df[df['People.Count'] >= 30]
clean_df2['People.Count'].describe()
# Out:
# count    870.000000
# mean     150.064368
# std       88.465192
# min       30.000000
# 25%       86.250000
# 50%      140.000000
# 75%      186.000000
# max      588.000000
# Name: People.Count, dtype: float64

# %%
clean_df3 = df[df['People.Count'] >= 20]
clean_df3['People.Count'].describe()
# Out:
# count    904.000000
# mean     145.330752
# std       90.031901
# min       20.000000
# 25%       79.000000
# 50%      137.000000
# 75%      184.250000
# max      588.000000
# Name: People.Count, dtype: float64

# %%
clean_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 904 entries, 0 to 2344
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                904 non-null    object
#  1   Accident.Number         904 non-null    object
#  2   Event.Date              904 non-null    object
#  3   Location                903 non-null    object
#  4   Injury.Severity         904 non-null    object
#  5   Registration.Number     877 non-null    object
#  6   Number.of.Engines       654 non-null    float64
#  7   Engine.Type             573 non-null    object
#  8   Total.Fatal.Injuries    904 non-null    float64
#  9   Total.Serious.Injuries  904 non-null    float64
#  10  Total.Minor.Injuries    904 non-null    float64
#  11  Total.Uninjured         904 non-null    float64
#  12  Make:Model              904 non-null    object
#  13  People.Count            904 non-null    float64
# ...

# %%
clean_df2["Location"].value_counts()
# Out:
# Location
# Chicago, IL              32
# Atlanta, GA              21
# Denver, CO               16
# New York, NY             15
# Los Angeles, CA          15
#                          ..
# Chantilly, VA             1
# Tripoli, Libya            1
# Sydney, Australia         1
# Mitu, Colombia            1
# Komatsu, Ishikawa, OF     1
# Name: count, Length: 511, dtype: int64

# %%
clean_df2.to_csv("clean_df1.csv")

# %%
file_path = "../Data/US.txt"
us_data = pd.read_csv(file_path, delimiter='\t')
# Out:
# /var/folders/px/v7992sbn36q0sd74xlm965340000gn/T/ipykernel_38830/940963581.py:2: DtypeWarning: Columns (9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   us_data = pd.read_csv(file_path, delimiter='\t')

# %%
us_data.head(50)
# Out:
#     2130830                     Middle Reef                   Middle Reef.1  \
# 0   2130833                   McArthur Reef                   McArthur Reef
# 1   2130890                     Buldir Reef                     Buldir Reef
# 2   3577483                     The Narrows                     The Narrows
# 3   3715657             Cape Lookout Shoals             Cape Lookout Shoals
# 4   3831601                Nantucket Shoals                Nantucket Shoals
# 5   3831610         Little Stellwagen Basin         Little Stellwagen Basin
# 6   3831661                    Cashes Ledge                    Cashes Ledge
# 7   3831676                      Ammen Rock                      Ammen Rock
# 8   3981608                   Tijuana River                   Tijuana River
# 9   4020151  Southern California Borderland  Southern California Borderland
# 10  4020231                     Osborn Bank                     Osborn Bank
# ...

# %%
us_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240900 entries, 0 to 2240899
# Data columns (total 19 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   2130830        int64
#  1   Middle Reef    object
#  2   Middle Reef.1  object
#  3   Unnamed: 3     object
#  4   51.98414       float64
#  5   176.01982      float64
#  6   U              object
#  7   RFU            object
#  8   US             object
#  9   Unnamed: 9     object
#  10  AK             object
#  11  Unnamed: 11    object
#  12  Unnamed: 12    float64
#  13  Unnamed: 13    float64
#  14  0              int64
#  15  Unnamed: 15    float64
#  16  -9999          int64
#  17  Unnamed: 17    object
#  18  2022-05-25     object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 324.8+ MB

# %%
us_data["2130830"].value_counts()
# Out:
# 2130830
# 2130833     1
# 5554267     1
# 5554261     1
# 5554262     1
# 5554263     1
#            ..
# 4804070     1
# 4804069     1
# 4804068     1
# 4804067     1
# 12626109    1
# Name: count, Length: 2240900, dtype: int64

# %%
state_names = {
    "AL": "Alabama", "AK": "Alaska", "AZ": "Arizona", "AR": "Arkansas", 
    "CA": "California", "CO": "Colorado", "CT": "Connecticut", "DE": "Delaware", 
    "FL": "Florida", "GA": "Georgia", "HI": "Hawaii", "ID": "Idaho", 
    "IL": "Illinois", "IN": "Indiana", "IA": "Iowa", "KS": "Kansas", 
    "KY": "Kentucky", "LA": "Louisiana", "ME": "Maine", "MD": "Maryland", 
    "MA": "Massachusetts", "MI": "Michigan", "MN": "Minnesota", "MS": "Mississippi", 
    "MO": "Missouri", "MT": "Montana", "NE": "Nebraska", "NV": "Nevada", 
    "NH": "New Hampshire", "NJ": "New Jersey", "NM": "New Mexico", "NY": "New York", 
    "NC": "North Carolina", "ND": "North Dakota", "OH": "Ohio", "OK": "Oklahoma", 
    "OR": "Oregon", "PA": "Pennsylvania", "RI": "Rhode Island", "SC": "South Carolina", 
    "SD": "South Dakota", "TN": "Tennessee", "TX": "Texas", "UT": "Utah", 
    "VT": "Vermont", "VA": "Virginia", "WA": "Washington", "WV": "West Virginia", 
    "WI": "Wisconsin", "WY": "Wyoming", "DC": "District of Columbia"
}

# %%
def split_location(location):
    if pd.isna(location):
        return [None, None]
    elif location == "Washington, DC":
        return ["Washington", "District of Columbia"]
    elif ',' in location:
        parts = [part.strip() for part in location.split(',', 1)]
        if parts[1] in state_names:
            parts[1] = state_names[parts[1]]  # Replace state abbreviation with full name
        return parts
    else:
        return [location, "Non-USA"]  # Assuming non-USA locations don't have a comma

# Applying the custom split function to the 'Location' column
clean_df2[['City', 'Region']] = clean_df2['Location'].apply(lambda x: split_location(x)).tolist()

# Dictionary mapping state abbreviations to full names, including DC
state_names = {
    # ... (same dictionary as before)
    "DC": "District of Columbia"
}

# Displaying the first few rows to confirm the changes
print(clean_df2[['City', 'Region']].head(50))
# Out:
#               City                Region
# 0           BOSTON         Massachusetts
# 1          CHICAGO              Illinois
# 3           BOSTON         Massachusetts
# 4     PHILADELPHIA          Pennsylvania
# 5          ONTARIO            California
# 6        HARLINGEN                 Texas
# 8       LONG BEACH            California
# 10      YOUNGSTOWN                  Ohio
# 11          AUSTIN                 Texas
# 12           MIAMI               Florida
# 14         MEMPHIS             Tennessee
# 15   SAN FRANCISCO            California
# 16     NEAR GOSHEN               Indiana
# 17  ATLANTIC OCEAN               Non-USA
# 19           BOISE                 Idaho
# 20        FLUSHING              New York
# 21          MORTON               Wyoming
# 22        FLUSHING              New York
# 23          DENVER              Colorado
# 24    NORTH PLATTE              Nebraska
# 25        HONOLULU                Hawaii
# 26      WASHINGTON  District of Columbia
# ...

# %%
state_names = {
    "AL": "Alabama", "AK": "Alaska", "AZ": "Arizona", "AR": "Arkansas", 
    "CA": "California", "CO": "Colorado", "CT": "Connecticut", "DE": "Delaware", 
    "FL": "Florida", "GA": "Georgia", "HI": "Hawaii", "ID": "Idaho", 
    "IL": "Illinois", "IN": "Indiana", "IA": "Iowa", "KS": "Kansas", 
    "KY": "Kentucky", "LA": "Louisiana", "ME": "Maine", "MD": "Maryland", 
    "MA": "Massachusetts", "MI": "Michigan", "MN": "Minnesota", "MS": "Mississippi", 
    "MO": "Missouri", "MT": "Montana", "NE": "Nebraska", "NV": "Nevada", 
    "NH": "New Hampshire", "NJ": "New Jersey", "NM": "New Mexico", "NY": "New York", 
    "NC": "North Carolina", "ND": "North Dakota", "OH": "Ohio", "OK": "Oklahoma", 
    "OR": "Oregon", "PA": "Pennsylvania", "RI": "Rhode Island", "SC": "South Carolina", 
    "SD": "South Dakota", "TN": "Tennessee", "TX": "Texas", "UT": "Utah", 
    "VT": "Vermont", "VA": "Virginia", "WA": "Washington", "WV": "West Virginia", 
    "WI": "Wisconsin", "WY": "Wyoming", "DC": "District of Columbia"
}

# Replacing state abbreviations with full names
clean_df2['Region'] = clean_df2['Region'].map(state_names)
# Out:
# /var/folders/px/v7992sbn36q0sd74xlm965340000gn/T/ipykernel_38318/2870987320.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df2['Region'] = clean_df2['Region'].map(state_names)

# %%
print(clean_df2[['City', 'Region']].head(50))
# Out:
#               City                Region
# 0           BOSTON         Massachusetts
# 1          CHICAGO              Illinois
# 3           BOSTON         Massachusetts
# 4     PHILADELPHIA          Pennsylvania
# 5          ONTARIO            California
# 6        HARLINGEN                 Texas
# 8       LONG BEACH            California
# 10      YOUNGSTOWN                  Ohio
# 11          AUSTIN                 Texas
# 12           MIAMI               Florida
# 14         MEMPHIS             Tennessee
# 15   SAN FRANCISCO            California
# 16     NEAR GOSHEN               Indiana
# 17  ATLANTIC OCEAN               Non-USA
# 19           BOISE                 Idaho
# 20        FLUSHING              New York
# 21          MORTON               Wyoming
# 22        FLUSHING              New York
# 23          DENVER              Colorado
# 24    NORTH PLATTE              Nebraska
# 25        HONOLULU                Hawaii
# 26      WASHINGTON  District of Columbia
# ...

# %%
print(clean_df2[['City', 'Region']].info)
# Out:
# <bound method DataFrame.info of               City         Region
# 0           BOSTON  Massachusetts
# 1          CHICAGO       Illinois
# 3           BOSTON  Massachusetts
# 4     PHILADELPHIA   Pennsylvania
# 5          ONTARIO     California
# ...            ...            ...
# 2325       Detroit       Michigan
# 2336   Los Angeles     California
# 2339        Manila
# 2340       Komatsu   Ishikawa, OF
# 2344         Miami        Florida
#
# [870 rows x 2 columns]>

# %%
clean_df2['City'] = clean_df2['City'].apply(lambda x: x.title() if pd.notna(x) else x)
print(clean_df2['City'].head(50))
# Out:
# 0             Boston
# 1            Chicago
# 3             Boston
# 4       Philadelphia
# 5            Ontario
# 6          Harlingen
# 8         Long Beach
# 10        Youngstown
# 11            Austin
# 12             Miami
# 14           Memphis
# 15     San Francisco
# 16       Near Goshen
# 17    Atlantic Ocean
# 19             Boise
# 20          Flushing
# 21            Morton
# 22          Flushing
# 23            Denver
# 24      North Platte
# 25          Honolulu
# 26        Washington
# 27           Houston
# 28            Austin
# 31            Denver
# 33             Miami
# 37            Denver
# 38          Pellston
# 39           Memphis
# 40        Washington
# 41           Thermal
# 42       Los Angeles
# 43       Los Angeles
# 44           Norfolk
# 45           Chicago
# 46       Los Angeles
# 47         Calverton
# 48           Durango
# 49          San Jose
# 50          Nr Tokyo
# 51       Panama City
# 52    Midway Islands
# 55            Boston
# ...

# %%
clean_df2.columns
# Out:
# Index(['Event.Id', 'Accident.Number', 'Event.Date', 'Location',
#        'Injury.Severity', 'Registration.Number', 'Number.of.Engines',
#        'Engine.Type', 'Total.Fatal.Injuries', 'Total.Serious.Injuries',
#        'Total.Minor.Injuries', 'Total.Uninjured', 'Make:Model', 'People.Count',
#        'City', 'Region'],
#       dtype='object')

# %%
def split_location(location):
    if pd.isna(location):
        return [None, None]
    elif 'Washington, DC' in location or 'Washington D.C.' in location:
        return ["Washington D.C.", "Non-USA"]  # Set 'Washington D.C.' in City and 'Non-USA' in Region
    elif ',' in location:
        parts = [part.strip() for part in location.split(',', 1)]
        return parts
    else:
        return [location, "Non-USA"]  # For non-USA locations

# Applying the custom split function to the 'Location' column
clean_df2[['City', 'Region']] = clean_df2['Location'].apply(lambda x: split_location(x)).tolist()

# Applying the .title() method to the 'City' column
clean_df2['City'] = clean_df2['City'].apply(lambda x: x.title() if pd.notna(x) else x)

# Displaying the first few rows to confirm the changes
print(clean_df2[['City', 'Region']].head(50))
# Out:
#               City      Region
# 0           Boston          MA
# 1          Chicago          IL
# 3           Boston          MA
# 4     Philadelphia          PA
# 5          Ontario          CA
# 6        Harlingen          TX
# 8       Long Beach          CA
# 10      Youngstown          OH
# 11          Austin          TX
# 12           Miami          FL
# 14         Memphis          TN
# 15   San Francisco          CA
# 16     Near Goshen          IN
# 17  Atlantic Ocean     Non-USA
# 19           Boise          ID
# 20        Flushing          NY
# 21          Morton          WY
# 22        Flushing          NY
# 23          Denver          CO
# 24    North Platte          NE
# 25        Honolulu          HI
# 26      Washington          DC
# 27         Houston          TX
# 28          Austin          TX
# 31          Denver          CO
# 33           Miami          FL
# 37          Denver          CO
# 38        Pellston          MI
# 39         Memphis          TN
# ...

# %%
clean_df1.to_csv("big_plane.csv", index=False)
