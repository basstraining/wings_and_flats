# %%
import pandas as pd

# %%
plane_df = pd.read_csv("../Data/Aviation_data.csv")
plane_df.head()
# Out:
# /var/folders/px/v7992sbn36q0sd74xlm965340000gn/T/ipykernel_31101/3463677682.py:1: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   plane_df = pd.read_csv("../Data/Aviation_data.csv")
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# ...

# %%
plane_df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
clean_plane_df = plane_df.drop(columns=['Country', 'Latitude', 'Longitude', 'Airport.Code',
       'Airport.Name',
       'Aircraft.Category',
       'Amateur.Built', 'Schedule', 'Air.carrier', 'Report.Status',
       'Publication.Date'])

# %%
clean_plane_df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location Injury.Severity Aircraft.damage Registration.Number  \
# 0  MOOSE CREEK, ID        Fatal(2)       Destroyed              NC6404
# 1   BRIDGEPORT, CA        Fatal(4)       Destroyed              N5069P
# 2    Saltville, VA        Fatal(3)       Destroyed              N5142R
# 3       EUREKA, CA        Fatal(2)       Destroyed              N1168J
# 4       Canton, OH        Fatal(1)       Destroyed               N15NY
#
#        Make     Model  Number.of.Engines    Engine.Type FAR.Description  \
# ...

# %%
clean_plane_df = clean_plane_df.dropna(subset=['FAR.Description']).query('`FAR.Description` != ["Part 91: General Aviation", "091"]')

# %%
clean_plane_df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5      20170710X52551           Accident      NYC79AA106  1979-09-17
# 22     20020917X01657           Accident      ATL82DA027  1982-01-02
# 33     20020917X02254           Accident      LAX82FA038  1982-01-04
# 39     20020917X01906           Accident      DCA82AA009  1982-01-05
# 43     20020917X02156           Accident      LAX82DA037  1982-01-05
# ...               ...                ...             ...         ...
# 90326  20221213106456           Accident      WPR23LA066  2022-12-12
# 90328  20221213106455           Accident      WPR23LA065  2022-12-13
# 90333  20221215106462           Accident      CEN23LA064  2022-12-15
# 90335  20221219106475           Accident      WPR23LA069  2022-12-15
# 90338  20221219106472           Accident      DCA23LA096  2022-12-18
#
#                  Location Injury.Severity Aircraft.damage Registration.Number  \
# ...

# %%
clean_plane_df["FAR.Description"].value_counts()
# Out:
# FAR.Description
# NUSN                              1584
# NUSC                              1013
# 137                               1010
# 135                                746
# 121                                679
# Part 137: Agricultural             437
# UNK                                371
# Part 135: Air Taxi & Commuter      298
# PUBU                               253
# 129                                246
# Part 121: Air Carrier              165
# 133                                107
# Part 129: Foreign                  100
# Non-U.S., Non-Commercial            97
# Non-U.S., Commercial                93
# Part 133: Rotorcraft Ext. Load      32
# Unknown                             22
# Public Use                          19
# 091K                                14
# ARMF                                 8
# Part 125: 20+ Pax,6000+ lbs          5
# 125                                  5
# 107                                  4
# ...

# %%
far_cols = ["135", "121", "Part 135", "129", "NUSC", "Part 121: Air Carrier", "Part 129: Foreign", "Non-U.S.,Commercial"]

# %%
clean_plane_df = clean_plane_df[clean_plane_df['FAR.Description'].isin(far_cols)]

# %%
clean_plane_df.head(20)
# Out:
#             Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5     20170710X52551           Accident      NYC79AA106  1979-09-17
# 79    20020917X01897           Incident      CHI82IA026  1982-01-12
# 129   20020917X02397           Accident      MIA82FA034  1982-01-19
# 149   20020917X01767           Incident      ATL82IA041  1982-01-22
# 155   20020917X01909           Accident      DCA82AA013  1982-01-23
# 230   20020917X01910           Accident      DCA82AA014  1982-02-03
# 320   20020917X02336           Incident      LAX82IA075  1982-02-15
# 336   20020917X01911           Accident      DCA82AA015  1982-02-16
# 351   20020917X02151           Incident      FTW82IA062  1982-02-19
# 506   20020917X02477           Incident      MKC82IA042  1982-03-08
# 522   20020917X02338           Incident      LAX82IA103  1982-03-10
# 676   20020917X01989           Incident      DEN82IA049  1982-03-25
# 796   20020917X01904           Incident      CHI82IA117  1982-04-09
# ...

# %%
clean_plane_df.isna().sum()
# Out:
# Event.Id                     0
# Investigation.Type           0
# Accident.Number              0
# Event.Date                   0
# Location                     7
# Injury.Severity            577
# Aircraft.damage            947
# Registration.Number        116
# Make                        30
# Model                       34
# Number.of.Engines         1122
# Engine.Type               1344
# FAR.Description              0
# Purpose.of.flight         2698
# Total.Fatal.Injuries       182
# Total.Serious.Injuries     172
# Total.Minor.Injuries       179
# Total.Uninjured             58
# Weather.Condition         1342
# Broad.phase.of.flight     2823
# dtype: int64

# %%
clean_plane_df["Aircraft.damage"].value_counts()
# Out:
# Aircraft.damage
# Substantial    1136
# Minor           537
# Destroyed       307
# Unknown          22
# Name: count, dtype: int64

# %%
clean_plane_df = clean_plane_df[clean_plane_df['Aircraft.damage'] != 'Unknown']

# %%
clean_plane_df["Aircraft.damage"].value_counts()
# Out:
# Aircraft.damage
# Substantial    1136
# Minor           537
# Destroyed       307
# Name: count, dtype: int64

# %%
clean_plane_df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count        1825.000000           2745.000000             2755.000000
# mean            1.829041              2.124954                0.808711
# std             0.671580             15.638572                5.968697
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             2.000000              0.000000                0.000000
# 75%             2.000000              0.000000                0.000000
# max             4.000000            295.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count           2748.000000      2869.000000
# mean               0.661572        47.269780
# std                8.525284        83.105655
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         3.000000
# ...

# %%
clean_plane_df.shape
# Out:
# (2927, 20)

# %%
clean_plane_df = clean_plane_df.drop(columns=["Purpose.of.flight"])

# %%
clean_plane_df.shape
# Out:
# (2927, 19)

# %%
clean_plane_df.head(10)
# Out:
#            Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5    20170710X52551           Accident      NYC79AA106  1979-09-17
# 79   20020917X01897           Incident      CHI82IA026  1982-01-12
# 129  20020917X02397           Accident      MIA82FA034  1982-01-19
# 149  20020917X01767           Incident      ATL82IA041  1982-01-22
# 155  20020917X01909           Accident      DCA82AA013  1982-01-23
# 230  20020917X01910           Accident      DCA82AA014  1982-02-03
# 320  20020917X02336           Incident      LAX82IA075  1982-02-15
# 336  20020917X01911           Accident      DCA82AA015  1982-02-16
# 351  20020917X02151           Incident      FTW82IA062  1982-02-19
# 506  20020917X02477           Incident      MKC82IA042  1982-03-08
#
#              Location Injury.Severity Aircraft.damage Registration.Number  \
# 5          BOSTON, MA       Non-Fatal     Substantial              CF-TLU
# 79        CHICAGO, IL        Incident             NaN              N31031
# ...

# %%
spec_cols = ["Total.Fatal.Injuries", "Total.Serious.Injuries", "Total.Minor.Injuries"]
clean_plane_df[spec_cols] = clean_plane_df[spec_cols].fillna(0)

# %%
clean_plane_df.head(10)
# Out:
#            Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5    20170710X52551           Accident      NYC79AA106  1979-09-17
# 79   20020917X01897           Incident      CHI82IA026  1982-01-12
# 129  20020917X02397           Accident      MIA82FA034  1982-01-19
# 149  20020917X01767           Incident      ATL82IA041  1982-01-22
# 155  20020917X01909           Accident      DCA82AA013  1982-01-23
# 230  20020917X01910           Accident      DCA82AA014  1982-02-03
# 320  20020917X02336           Incident      LAX82IA075  1982-02-15
# 336  20020917X01911           Accident      DCA82AA015  1982-02-16
# 351  20020917X02151           Incident      FTW82IA062  1982-02-19
# 506  20020917X02477           Incident      MKC82IA042  1982-03-08
#
#              Location Injury.Severity Aircraft.damage Registration.Number  \
# 5          BOSTON, MA       Non-Fatal     Substantial              CF-TLU
# 79        CHICAGO, IL        Incident             NaN              N31031
# ...

# %%
clean_plane_df["Make"].value_counts()
# Out:
# Make
# BOEING                            832
# CESSNA                            286
# Boeing                            221
# AIRBUS                            192
# PIPER                             103
#                                  ...
# AMERICAN EUROCOPTER LLC             1
# AgustadWestland                     1
# BOEING COMPANY, LONG BEACH DIV      1
# Hawker Beechcraft Corporation       1
# GARLICK                             1
# Name: count, Length: 215, dtype: int64

# %%
pd.set_option('display.max_rows', None)
print (clean_plane_df['Make'].value_counts())
# Out:
# Make
# BOEING                            832
# CESSNA                            286
# Boeing                            221
# AIRBUS                            192
# PIPER                             103
# BELL                               90
# BEECH                              87
# EMBRAER                            86
# MCDONNELL DOUGLAS                  58
# BOMBARDIER INC                     56
# Cessna                             54
# Mcdonnell Douglas                  44
# DEHAVILLAND                        43
# EUROCOPTER                         37
# BOMBARDIER                         30
# SIKORSKY                           25
# Airbus                             22
# Embraer                            21
# Airbus Industrie                   20
# ROBINSON                           20
# AIRBUS INDUSTRIE                   20
# Bell                               19
# Beech                              16
# Douglas                            16
# ...

# %%
clean_plane_df['Make'] = clean_plane_df['Make'].str.title()
pd.set_option('display.max_rows', None)
print(clean_plane_df['Make'].value_counts())
# Out:
# Make
# Boeing                            1053
# Cessna                             340
# Airbus                             214
# Piper                              118
# Bell                               109
# Embraer                            107
# Mcdonnell Douglas                  104
# Beech                              103
# Bombardier Inc                      56
# Dehavilland                         45
# Airbus Industrie                    40
# Eurocopter                          40
# Bombardier                          37
# Douglas                             30
# Sikorsky                            30
# De Havilland                        27
# Robinson                            25
# Aerospatiale                        15
# Fairchild                           14
# Swearingen                          13
# Agusta                              12
# Eurocopter Deutschland Gmbh         11
# Fokker                              11
# Lockheed                            11
# ...

# %%
clean_plane_df.head()
# Out:
#            Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5    20170710X52551           Accident      NYC79AA106  1979-09-17
# 79   20020917X01897           Incident      CHI82IA026  1982-01-12
# 129  20020917X02397           Accident      MIA82FA034  1982-01-19
# 149  20020917X01767           Incident      ATL82IA041  1982-01-22
# 155  20020917X01909           Accident      DCA82AA013  1982-01-23
#
#            Location Injury.Severity Aircraft.damage Registration.Number  \
# 5        BOSTON, MA       Non-Fatal     Substantial              CF-TLU
# 79      CHICAGO, IL        Incident             NaN              N31031
# 129       MIAMI, FL       Non-Fatal     Substantial               HCBHS
# 149  LOUISVILLE, KY        Incident             NaN               N18FE
# 155      BOSTON, MA        Fatal(2)       Destroyed              N113WA
#
#                   Make      Model  Number.of.Engines Engine.Type  \
# ...

# %%
new_df = plane_df.drop(columns=['Country', 'Latitude', 'Longitude', 'Airport.Code',
       'Airport.Name',
       'Amateur.Built', 'Schedule', 'Air.carrier', 'Report.Status',
       'Publication.Date'])

# %%
new_df = new_df.dropna(subset=['FAR.Description']).query('`FAR.Description` != ["Part 91: General Aviation", "091"]')

# %%
new_df = new_df[new_df['FAR.Description'].isin(far_cols)]

# %%
new_df = new_df[new_df['Aircraft.damage'] != 'Unknown']

# %%
new_df = new_df.drop(columns=["Purpose.of.flight"])

# %%
new_df[spec_cols] = new_df[spec_cols].fillna(0)

# %%
new_df['Make'] = new_df['Make'].str.title()

# %%
new_df.head(10)
# Out:
#            Event.Id Investigation.Type Accident.Number  Event.Date  \
# 5    20170710X52551           Accident      NYC79AA106  1979-09-17
# 79   20020917X01897           Incident      CHI82IA026  1982-01-12
# 129  20020917X02397           Accident      MIA82FA034  1982-01-19
# 149  20020917X01767           Incident      ATL82IA041  1982-01-22
# 155  20020917X01909           Accident      DCA82AA013  1982-01-23
# 230  20020917X01910           Accident      DCA82AA014  1982-02-03
# 320  20020917X02336           Incident      LAX82IA075  1982-02-15
# 336  20020917X01911           Accident      DCA82AA015  1982-02-16
# 351  20020917X02151           Incident      FTW82IA062  1982-02-19
# 506  20020917X02477           Incident      MKC82IA042  1982-03-08
#
#              Location Injury.Severity Aircraft.damage Aircraft.Category  \
# 5          BOSTON, MA       Non-Fatal     Substantial          Airplane
# 79        CHICAGO, IL        Incident             NaN          Airplane
# ...

# %%
new_df = new_df[new_df['Aircraft.Category'] == 'Airplane']

# %%
new_df['Aircraft.Category'].value_counts()
# Out:
# Aircraft.Category
# Airplane    2434
# Name: count, dtype: int64

# %%
new_df['Make'].value_counts()
# Out:
# Make
# Boeing                            973
# Cessna                            333
# Airbus                            191
# Piper                             115
# Embraer                           106
# Mcdonnell Douglas                 100
# Beech                              97
# Bombardier Inc                     53
# Dehavilland                        45
# Airbus Industrie                   39
# Bombardier                         33
# Douglas                            30
# De Havilland                       24
# Fairchild                          14
# Swearingen                         11
# Lockheed                           11
# Fokker                             10
# Helio                               9
# Aero Commander                      8
# Bae                                 8
# Learjet                             8
# Atr                                 7
# Raytheon Aircraft Company           7
# Embraer S A                         7
# ...

# %%
new_df.to_csv('new_df.csv', index=False)
